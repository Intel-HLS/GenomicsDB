# %% [markdown]
# ## For new version of result processing

# %%
# %load_ext autoreload
# %autoreload 2

from py_report.variant_density_results import VariantDensityResult, BY_CPU, BY_TIME
handler = VariantDensityResult()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for i in range(0, 4, 2):
    handler.compare_group_by_eids([(i, i+1)], None, BY_TIME)
    handler.compare_group_by_eids([(i+1, i)], None, BY_CPU)
# Out:
# INFO no stat available: ['12::iostat_1-qc_sparse_65_1-1.log', '13::iostat_1-qc_sparse_65_1-1.log']
# <style>tr:nth-of-type(even) {background-color:#FAFAD2;}</style><table>
# <thead>
# <tr><th>                               </th><th>density  </th><th style="text-align: right;">  num_pos</th><th style="text-align: right;">      r/s</th><th style="text-align: right;">    rkB/s</th><th style="text-align: right;">  avgrq-sz</th><th style="text-align: right;">    avgqu-sz</th><th style="text-align: right;">    r_await</th><th style="text-align: right;">    %util</th></tr>
# </thead>
# <tbody>
# <tr><td>HDD with Refblock and 1 mpirun </td><td>dense    </td><td style="text-align: right;">     1000</td><td style="text-align: right;"> 129.13  </td><td style="text-align: right;"> 12827.3 </td><td style="text-align: right;">  197.641 </td><td style="text-align: right;">  0.717431  </td><td style="text-align: right;">  5.60146  </td><td style="text-align: right;">55.144   </td></tr>
# ...
