# %% [markdown]
# <center><h2>Density Profiling of 16 Patitions on SSD and HDD Ref Block with Zlib</h2></center>
#
# This report contains 2 experiments:
# 1. Query 16 partitions Full GenomicsDB (with REF blocks) on <b>SSD</b> with Intel Zlib
# 2. Query 16 partitions Full GenomicsDB (with REF blocks) on <b>HDD</b> with Intel Zlib
#
# Each test picks <strong>65</strong> and <strong>1000</strong> positions from dense, intermediate and sparse variant regions in a partition respectively, then generates genomics query config files (total 6) accordingly.
#
# For each genomics query config file, run query with <em>segment_size, in byte</em> <strong>1000, 5000, 10000</strong> respectively. Repeat each setting 3 times, total <b><i>54</i></b> runs.
#
# Total number of query positions for 65 is 1040 (16x65) and for 1000 is 16000.
#
# Query <b>1000</b> positions over <b>1 partitions</b> is about <b>17 sec, 45 sec and 70 sec</b> for sparse, intermediate and dense regions). With <b>16 partitions</b>, the query times are reduced to <b>4 sec, 6 sec and 6 sec</b>
#
# The graphs show:
#
# * [Wall Clock](#wall_clock) for each test and result comparison
# * [CPU%](#cpu_percentile) for each test and result comparison
# * [iostats](#iostat) of all tests that were measured.
#
# Color convention:
#
# * <span style="color:blue"><b>Sparse Region</b></span>
# * <span style="color:red"><b>Intermediate Region</b></span>
# * <span style="color:green"><b>Dense Region</b></span>
#
# The <em>segment_size</em> is represented in diffent color shade and marked as <i>SSnnnn</i> in graph legend.
#
# The profiling were performed at hosts compute-2-28 and compute-2-29:

# %%
import sys, os, os.path
import pandas as pd

root_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if not root_path in sys.path:
    sys.path.append(root_path)
from py_scratch.u_parse_plot_result import *
test_root = os.path.join(root_path, '..', 'run_logs')
target_proj='variant-density'

# %% [markdown]
# ### 16 Partitions using Intel Zlib with Full GenomicsDB, with SSD and HDD
#
# #### <a name="wall_clock">Wall Clock</a>
#
# The following graphs show the <b>wall clock</b> of SSD.

# %%
target_run='e-31_16_ssd_iazlib_refblock'
target_run2='e-30_16_hdd_oszlib_refblock'
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run), ('variant-density',target_run2)], 1)

# %%
target_run='e-33_16_ssd_iazlib_varonly'
target_run2='e-32_16_hdd_oszlib_varonly'
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run), ('variant-density',target_run2)], 1)
# Out:
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 16 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-33_16_ssd_iazlib_varonly/16-lc_pos_variant-density.json
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 16 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-32_16_hdd_oszlib_varonly/16-lc_pos_variant-density.json

# %%
target_run='e-33_16_ssd_iazlib_varonly'
target_run2='e-31_16_ssd_iazlib_refblock'
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run), ('variant-density',target_run2)], 1)
# Out:
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 16 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-33_16_ssd_iazlib_varonly/16-lc_pos_variant-density.json

# %%
target_run='e-41_44_ssd_iazlib_refblock'
target_run2='e-40_44_hdd_oszlib_refblock'
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run), ('variant-density',target_run2)], 1)
# Out:
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 44 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-41_44_ssd_iazlib_refblock/44-lc_pos_variant-density.json
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 44 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-40_44_hdd_oszlib_refblock/44-lc_pos_variant-density.json

# %%
target_run='e-43_44_ssd_iazlib_varonly'
target_run2='e-42_44_hdd_oszlib_varonly'
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run), ('variant-density',target_run2)], 1)
# Out:
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 44 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-43_44_ssd_iazlib_varonly/44-lc_pos_variant-density.json
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 44 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-42_44_hdd_oszlib_varonly/44-lc_pos_variant-density.json

# %%
target_run='e-31_16_ssd_iazlib_refblock'
target_run2='e-41_44_ssd_iazlib_refblock'
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run), ('variant-density',target_run2)], 1)
# Out:
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 44 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-41_44_ssd_iazlib_refblock/44-lc_pos_variant-density.json

# %%
exps = [
        ('variant-density', target_run),
        ('variant-density',target_run2),
       ]
dfs = get_stats(test_root, exps)
for name, df in dfs.items():
    print()
    print("---------------- For %s%s Region---------------" % (name[0], name[1:]))
    print(df)
# Out:
# WARN: cannot find C:\Users\mrutarx\myprojects\GenomicsDBPerfTest\dev_apps\..\run_logs\variant-density\e-31_16_ssd_iazlib_refblock\compute-2-28\sampling\iostat_16-qc_sparse_1000_1-1.cvs
# WARN: cannot find C:\Users\mrutarx\myprojects\GenomicsDBPerfTest\dev_apps\..\run_logs\variant-density\e-41_44_ssd_iazlib_refblock\compute-2-28\sampling\iostat_16-qc_sparse_1000_1-1.cvs
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a8798e9b5644> in <module>()
#       3         ('variant-density',target_run2),
#       4        ]
# ----> 5 dfs = get_stats(test_root, exps)
#       6 for name, df in dfs.items():
#       7     print()
#
# C:\Users\mrutarx\myprojects\GenomicsDBPerfTest\dev_apps\py_scratch\u_parse_plot_result.py in get_stats(my_test_root, test_list)
#     485             fname = os.path.basename(cvs_fn)                    #'iostat_1-qc_pos_1000_1-1.cvs'
#     486             dname, _ = density_name(fname)
# --> 487             stat_data[dname].extend(mean_list)
#     488     index = [x[1][x[1].find('_')+1:] for x in old_exp_list + new_exp_list]
#     489     print('iostats for tests: ', ", ".join(index))
#
# KeyError: 'sparse'

# %% [markdown]
# #### <a name="cpu_percentile">CPU%</a>
#
# ###### <i>CPU%</i> of 16 partitions, Zlib, Ref-block, <i>SSD</i> (e-11_16_ssd_zlib_refblock)
# Parallel query with <b>mpirun</b>. the number in graph show the total CPU usage of 16 parallel quering.

# %%
_, _ = gen_report_graph(test_root, target_proj, target_run, 1, 1)

# %% [markdown]
# ###### <i>CPU%</i> of 16 partitions, Zlib, Ref-block, <i>HHD</i> (e-10_16_hdd_zlib_refblock)
# Parallel query with <b>mpirun</b>. the number in graph show the total CPU usage of 16 parallel quering.

# %%
_, _ = gen_report_graph(test_root, target_proj, target_run2, 1, 1)
# Out:
# INFO skipped non-"gt_mpi_gather", cmd /usr/lib64/mpich/bin/mpirun -np 44 /home/mingrutar/docker-geno/Release/bin/vcf2tiledb /home/mingrutar/GenomicsDBPerfTest/run_tests/variant-density/e-41_44_ssd_iazlib_refblock/44-lc_pos_variant-density.json

# %% [markdown]
# ##### CPU% Comparison HDD vs SSD
#
# * E-11 (e-11_16_ssd_zlib_refblock) is HDD
# * E-10 (e-10_16_hdd_zlib_refblock) is SSD

# %%
_ = gen_pair_diff_graph(test_root, [('variant-density', target_run2), ('variant-density',target_run)], 1, 1)

# %% [markdown]
# ### <a name='iostat'></a>Results of iostat Profiling
#
# The sampling interval is <b>1 second</b>. I only collected data for 1000 postitions with Segment Size 10000.
#
# The table show the average values of iostat logs for profiling
# * <b>e-7_zlib</b>:     Intel zlib on HDD
# * <b>e-6_ssd</b>:      Linux zlib on SSD
# * <b>e-8_zlib_ssd</b>: Intel zlib on SSD
# * <b>e-5_var_only</b>: Linux zlib on HDD
# * <b>e-8_zlib_ssd</b>: Intel zlib on SSD using full DB

# %%
exps = [
        ('variant-density', 'e-11_16_ssd_zlib_refblock'),
        ('variant-density','e-10_16_hdd_zlib_refblock'),
        ('variant-density','e-9_1_ssd_zlib_refblock'),
        ('variant-density','e-3_ref_block'),
        ('variant-density_noref', 'e-8_zlib_ssd'), 
        ('variant-density_noref', 'e-7_zlib'),
        ('variant-density_noref', 'e-6_ssd'),
        ('variant-density_noref', 'e-5_var_only')
       ]
old_test_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..', 'dev_scratch', 'logs'))

dfs = get_stats(old_test_root, exps)
for name, df in dfs.items():
    print()
    print("---------------- For %s%s Region---------------" % (name[0], name[1:]))
    print(df)
# Out:
# iostats for tests:  1_ssd_zlib_refblock, ref_block, zlib_ssd, zlib, ssd, var_only, 16_ssd_zlib_refblock, 16_hdd_zlib_refblock
#
# ---------------- For dense Region---------------
#                           %util   avgqu-sz    avgrq-sz          r/s    r_await          rkB/s
# 1_ssd_zlib_refblock   14.111897   0.153448  222.354138   285.270862   0.543103   31868.423966
# ref_block             30.208955   0.350149  214.666567   125.388060   2.782239   13462.328358
# zlib_ssd               9.997297   0.110270  215.973514   221.594595   0.503514   23914.594595
# zlib                  31.592754   0.376087  216.649710   121.391304   3.066812   13146.318841
# ssd                   10.934286   0.120857  212.721143   239.514286   0.524857   25492.571429
# var_only              36.173733   0.422267  214.922533   112.140000   3.711733   11988.359067
# 16_ssd_zlib_refblock  61.594605   1.238421  209.372368  1614.713553   0.753026  169064.402237
# 16_hdd_zlib_refblock  98.838047  17.537348  209.556738   216.020305  79.635323   22629.410609
#
# ---------------- For intermediate Region---------------
#                           %util   avgqu-sz    avgrq-sz          r/s    r_await          rkB/s
# 1_ssd_zlib_refblock   14.947222   0.161852  207.723148   306.928333   0.495741   34426.844074
# ref_block             52.636585   0.689756  221.471463   211.073171   3.337561   23310.146341
# zlib_ssd              17.618182   0.203182  220.844091   385.909091   0.526364   42386.363636
# zlib                  51.009302   0.699070  221.039767   204.674419   3.427442   22519.720930
# ssd                   19.731579   0.235263  221.377895   441.157895   0.536842   48306.315789
# var_only              60.767347   0.882449  220.597959   182.183673   5.095714   19942.612245
# 16_ssd_zlib_refblock  35.762400   0.888880  144.937680  1022.443840   0.519280  107633.803760
# 16_hdd_zlib_refblock  99.667915  16.983880  211.008222   213.992667  78.281573   22562.680479
#
# ---------------- For sparse Region---------------
#                           %util  avgqu-sz    avgrq-sz        r/s    r_await        rkB/s
# 1_ssd_zlib_refblock    1.037209  0.010930  155.039767  31.744186   0.446047  3908.465116
# ref_block              2.557143  0.032143  101.992857   8.071429   3.123571   885.142857
# zlib_ssd               0.392857  0.003571   83.534286   8.642857   0.270714   906.000000
# zlib                   2.506667  0.035333   95.857333   7.800000   2.664667   851.466667
# ssd                    0.346154  0.003846   90.453077   8.461538   0.293077   933.538462
# var_only               2.907143  0.039286   92.197857   8.714286   1.538571   914.571429
# 16_ssd_zlib_refblock   3.034667  0.033733  145.446800  60.453333   0.378400  7046.933333
# 16_hdd_zlib_refblock  46.384706  2.772235  149.730706  68.141176  21.447294  7986.588235
